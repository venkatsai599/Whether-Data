# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from keras.layers import Dense

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Weather Data set

# %%
dir_path_dataset_1 = 'C:/Users/anand/Downloads/Weather report 2008 -2010.csv'

# %% [markdown]
# ### Load Dataset

# %%
df_ALL = pd.read_csv('C:/Users/anand/Downloads/Weather report 2008 -2010.csv')

# %%
df_ALL.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...          71           22
# 1         WNW           44.0        NNW  ...          44           25
# 2         WSW           46.0          W  ...          38           30
# 3          NE           24.0         SE  ...          45           16
# 4           W           41.0        ENE  ...          82           33
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Breif Exploratory Data Analysis

# %%
df_ALL.shape
# Out:
# (500, 23)

# %%
df_ALL.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# ### Statistics summary

# %%
df_ALL.describe()
# Out:
#           MinTemp    MaxTemp    Rainfall  Evaporation  Sunshine  \
# count  500.000000  500.00000  495.000000          0.0       0.0
# mean    11.113600   24.87640    1.508283          NaN       NaN
# std      6.091241    8.22335    5.040909          NaN       NaN
# min     -2.000000    8.20000    0.000000          NaN       NaN
# 25%      6.500000   17.67500    0.000000          NaN       NaN
# 50%     11.300000   25.30000    0.000000          NaN       NaN
# 75%     15.600000   31.30000    0.400000          NaN       NaN
# max     28.300000   44.80000   66.000000          NaN       NaN
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     494.000000    497.000000    497.000000   500.000000   500.000000
# mean       35.259109      8.376258     14.919517    67.006000    40.938000
# std        14.723884      7.072014      7.867704    18.291723    20.660878
# min        11.000000      0.000000      0.000000    20.000000     7.000000
# 25%        24.000000      4.000000      9.000000    51.000000    24.000000
# 50%        33.000000      7.000000     13.000000    68.000000    38.000000
# 75%        43.750000     11.000000     20.000000    82.000000    56.000000
# max       107.000000     37.000000     50.000000    99.000000    97.000000
#
#        Pressure9am  Pressure3pm    Cloud9am    Cloud3pm     Temp9am  \
# count   500.000000   500.000000  164.000000  176.000000  500.000000
# mean   1016.781600  1013.996600    6.103659    5.113636   15.920200
# std       6.859686     6.702245    2.575531    2.921572    6.466502
# min     994.300000   993.000000    0.000000    1.000000    1.900000
# 25%    1011.600000  1008.800000    4.000000    2.000000   10.575000
# 50%    1016.650000  1013.750000    8.000000    6.000000   16.000000
# 75%    1021.925000  1019.025000    8.000000    8.000000   20.825000
# max    1036.300000  1033.600000    8.000000    8.000000   34.500000
#
#           Temp3pm
# count  500.000000
# mean    23.615800
# std      8.002743
# min      7.300000
# 25%     16.675000
# 50%     24.100000
# 75%     29.725000
# max     43.400000

# %%
### Filtering all other atributes

# %%
df = df_ALL.iloc[:,3:4]

# %%
df.head()
# Out:
#    MaxTemp
# 0     22.9
# 1     25.1
# 2     25.7
# 3     28.0
# 4     32.3

# %%
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
length60=60

# %%
length60
# Out:
# 60

# %% [markdown]
# ###Time Series Dataste: Train / test Split

# %%
len(df)
# Out:
# 500

# %%
test_percent = 0.1

# %%
len(df)*test_percent
# Out:
# 50.0

# %% [markdown]
# ### Split-> Train /test

# %%
test_length= np.round(len(df)*test_percent)
test_length
# Out:
# 50.0

# %%
split_index = int(len(df) - test_length)

split_index
# Out:
# 450

# %%
data_train= df.iloc[: split_index]
data_test = df.iloc[split_index - length60 :]

# %%
data_train.head(5)
# Out:
#    MaxTemp
# 0     22.9
# 1     25.1
# 2     25.7
# 3     28.0
# 4     32.3

# %%
data_train.tail()
# Out:
#      MaxTemp
# 445     34.7
# 446     26.4
# 447     26.1
# 448     28.5
# 449     31.0

# %%
data_test.head(5)
# Out:
#      MaxTemp
# 390     27.3
# 391     35.9
# 392     35.9
# 393     36.8
# 394     33.2

# %%
data_test.tail()
# Out:
#      MaxTemp
# 495     25.1
# 496     25.9
# 497     25.2
# 498     27.5
# 499     27.3

# %% [markdown]
# ### Normalize Data (scaling)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(data_train)
# Out:
# MinMaxScaler()

# %%
normalized_train= scaler.transform(data_train)
normalized_test = scaler.transform(data_test)

# %% [markdown]
# ### Create TimeseriesGenerator for Training

# %%
batch_size32 = 32
train_tsGenerator60 = TimeseriesGenerator(normalized_train, normalized_train, length=length60, batch_size=batch_size32)

# %%
len(normalized_train)
# Out:
# 450

# %%
len(train_tsGenerator60)
# Out:
# 13

# %%
X,Y = train_tsGenerator60[0]

# %% [markdown]
# ### Build, Train and test Model

# %%
n_features = 1

# %%
## Define Model
model = Sequential()

# Add an LSTM Layer
# This Layer has 50 LSTM Cells
# Activation Function: relu
# MUST: return_sequences=True
#-----> Because of multiple LSTM layers: the layers are stacked
#-----> Outputs = inputs of the next LSTM layer
model.add(LSTM(150, activation='relu', return_sequences=True, input_shape=(length60, n_features)))

## Dropout Layer
model.add(Dropout(0.1))

## Add 2nd LSTM Layer
# MUST: return_sequences=True
#----> Because of multiple LSTM layers: Layers are Stacked
#----> Outputs = inputs of the next LSTM layer
model.add(LSTM(units=50, activation='relu', return_sequences=True))

## Dropout Layer
model.add(Dropout(0.1))

## Add 3rd LSTM Layer
model.add(LSTM(units=150, activation='relu'))

#Add a FC (fully-connected) layer for the final prediction
model.add(Dense(1))

##Procedure:
#Time Series Input---> LSTM --->Dropout --->LSTM --->Droput --->LSTM --->Dense --->Output

# %% [markdown]
# ### Compile Model

# %%
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 150)           91200
#
#  dropout (Dropout)           (None, 60, 150)           0
#
#  lstm_1 (LSTM)               (None, 60, 50)            40200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 150)               120600
#
#  dense (Dense)               (None, 1)                 151
#
# =================================================================
# Total params: 252,151
# Trainable params: 252,151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train (fit) model Using fit_generator()

# %%
## Train the Model

model.fit_generator(train_tsGenerator60, epochs=100)
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_15060\1790817069.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0132
# Epoch 78/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0123
# Epoch 79/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0122
# Epoch 80/100
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0123
# Epoch 81/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0122
# Epoch 82/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0121
# Epoch 83/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0125
# Epoch 84/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0126
# Epoch 85/100
# 13/13 [==============================] - 2s 155ms/step - loss: 0.0120
# Epoch 86/100
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0146
# Epoch 87/100
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0123
# Epoch 88/100
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0122
# Epoch 89/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0125
# Epoch 90/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0127
# Epoch 91/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0120
# Epoch 92/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0118
# Epoch 93/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0117
# Epoch 94/100
# 13/13 [==============================] - 2s 166ms/step - loss: 0.0122
# Epoch 95/100
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0119
# Epoch 96/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0118
# Epoch 97/100
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0114
# Epoch 98/100
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0120
# Epoch 99/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0119
# Epoch 100/100
# 13/13 [==============================] - 2s 155ms/step - loss: 0.0126

# %% [markdown]
# ### Visulaize Model's PErformance after Training

# %%
loss_history_keys = model.history.history.keys()
loss_history_keys
# Out:
# dict_keys(['loss'])

# %%
df_model_loss = pd.DataFrame(model.history.history)


df_model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
### Prediction for Testing : using Timeseries Genrator

# %%
batch_size1= 1
test_tsGenerator60 = TimeseriesGenerator(normalized_test, normalized_test, length=length60, batch_size=batch_size1)

# %%
normalized_prediction=model.predict_generator (test_tsGenerator60)
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_15060\2645534869.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   normalized_prediction=model.predict_generator (test_tsGenerator60)

# %%
normalized_prediction
# Out:
# array([[0.5871168 ],
#        [0.58569753],
#        [0.5836454 ],
#        [0.585816  ],
#        [0.58873177],
#        [0.57736117],
#        [0.56311995],
#        [0.5416657 ],
#        [0.52092516],
#        [0.5030116 ],
#        [0.4893884 ],
#        [0.48051465],
#        [0.4758168 ],
#        [0.4783787 ],
#        [0.48821855],
#        [0.5042015 ],
#        [0.5248433 ],
#        [0.54742277],
#        [0.55721116],
#        [0.5568093 ],
#        [0.5534482 ],
#        [0.55244887],
#        [0.5547952 ],
#        [0.5598552 ],
#        [0.56643945],
#        [0.5707882 ],
#        [0.5687137 ],
#        [0.56398594],
#        [0.55635345],
#        [0.5468377 ],
#        [0.53526574],
#        [0.5223843 ],
#        [0.5093068 ],
#        [0.49771643],
#        [0.486502  ],
#        [0.47348642],
#        [0.45907557],
#        [0.44209749],
#        [0.41842508],
#        [0.3914734 ],
#        [0.36234033],
#        [0.33683485],
#        [0.3187347 ],
#        [0.3102587 ],
#        [0.31314737],
#        [0.32636416],
#        [0.346085  ],
#        [0.3705256 ],
#        [0.39513987],
#        [0.42227602]], dtype=float32)

# %%
len(normalized_prediction)
# Out:
# 50

# %%
prediction = scaler.inverse_transform(normalized_prediction)

# %%
prediction_index = np.arange(166, 166+len(prediction), step=1)

df_prediction = pd.DataFrame(data=prediction,index=prediction_index, columns=['prediction'])

# %%
df_prediction
# Out:
#      prediction
# 166   29.688475
# 167   29.636530
# 168   29.561422
# 169   29.640867
# 170   29.747583
# 171   29.331419
# 172   28.810190
# 173   28.024963
# 174   27.265862
# 175   26.610224
# 176   26.111616
# 177   25.786837
# 178   25.614895
# 179   25.708662
# 180   26.068800
# 181   26.653774
# 182   27.409264
# 183   28.235674
# 184   28.593929
# 185   28.579222
# 186   28.456205
# 187   28.419628
# 188   28.505505
# 189   28.690702
# 190   28.931684
# 191   29.090849
# 192   29.014923
# 193   28.841887
# 194   28.562536
# 195   28.214260
# 196   27.790726
# 197   27.319265
# 198   26.840630
# 199   26.416422
# 200   26.005974
# 201   25.529604
# 202   25.002167
# 203   24.380768
# 204   23.514359
# 205   22.527927
# 206   21.461657
# 207   20.528156
# 208   19.865690
# 209   19.555468
# 210   19.661194
# 211   20.144928
# 212   20.866713
# 213   21.761238
# 214   22.662119
# 215   23.655302

# %% [markdown]
# ### Visulaize Predictions

# %%
ax = data_train.plot()

df_prediction.plot(ax=ax, figsize=(8, 12))
# Out:
# <AxesSubplot:>

# %%
full_scaler= MinMaxScaler()
normalized_full_data=full_scaler.fit_transform(df)

# %% [markdown]
# ### Create Timeseries GEnerator for Forecasting

# %%
length60
# Out:
# 60

# %%
forecast_tsGenerator = TimeseriesGenerator(normalized_train, normalized_train, length=length60, batch_size=batch_size32)

# %% [markdown]
# ### Build Compile and Fit LTSM model for forecasting

# %%
model.fit_generator(forecast_tsGenerator, epochs=100)
# Out:
# Epoch 1/100
# C:\Users\anand\AppData\Local\Temp\ipykernel_15060\199224003.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(forecast_tsGenerator, epochs=100)
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0124
# Epoch 2/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0118
# Epoch 3/100
# 13/13 [==============================] - 2s 165ms/step - loss: 0.0147
# Epoch 4/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0139
# Epoch 5/100
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0136
# Epoch 6/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0133
# Epoch 7/100
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0099
# Epoch 83/100
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0095
# Epoch 84/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0088
# Epoch 85/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0087
# Epoch 86/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0080
# Epoch 87/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0080
# Epoch 88/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0087
# Epoch 89/100
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0074
# Epoch 90/100
# 13/13 [==============================] - 2s 153ms/step - loss: 0.0084
# Epoch 91/100
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0081
# Epoch 92/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0081
# Epoch 93/100
# 13/13 [==============================] - 2s 155ms/step - loss: 0.0093
# Epoch 94/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0085
# Epoch 95/100
# 13/13 [==============================] - 2s 153ms/step - loss: 0.0087
# Epoch 96/100
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0080
# Epoch 97/100
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0077
# Epoch 98/100
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0085
# Epoch 99/100
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0079
# Epoch 100/100
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0085

# %% [markdown]
# ### Time Series Forecast Using LSTM Nueural Network

# %%
periods = 50

# Selecting the last 60 timesteps from the training dataset
first_eval_batch = normalized_full_data[-length60:]
current_batch = first_eval_batch.reshape((1, length60, n_features))
forecast = []
# Generating the forecasts for the next 50 days
for i in range(periods):
    # Make a prediction with the current batch
    current_pred = model.predict(current_batch)[0]
    # Append the prediction to the forecast list
    forecast.append(current_pred)
    # Create a new batch with the predicted value and the previous 59 values
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
# Out:
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# ###  inverse to transform

# %%
MaxTemp = full_scaler.inverse_transform(forecast)
MaxTemp
# Out:
# array([[24.83165639],
#        [24.23502866],
#        [23.96255229],
#        [24.09051648],
#        [24.55007977],
#        [25.20589023],
#        [25.92357433],
#        [26.59768019],
#        [27.1631284 ],
#        [27.58256463],
#        [27.86464736],
#        [28.05489205],
#        [28.20288923],
#        [28.34844964],
#        [28.51333622],
#        [28.70150627],
#        [28.89891946],
#        [29.08831117],
#        [29.2542667 ],
#        [29.38732913],
#        [29.49054822],
#        [29.57237086],
#        [29.63993067],
#        [29.70005363],
#        [29.75780746],
#        [29.8139644 ],
#        [29.86698867],
#        [29.91487325],
#        [29.95511594],
#        [29.98718225],
#        [30.0120386 ],
#        [30.03199306],
#        [30.04889773],
#        [30.06395247],
#        [30.07750413],
#        [30.08961381],
#        [30.10017023],
#        [30.10892035],
#        [30.1157769 ],
#        [30.12083586],
#        [30.12447684],
#        [30.12700741],
#        [30.12870028],
#        [30.1298085 ],
#        [30.13077492],
#        [30.13195294],
#        [30.1333513 ],
#        [30.13478239],
#        [30.1360324 ],
#        [30.13695083]])

# %%
### creating new timestamp index with pandas

# %%
MaxTemp_index = np.arange(1382, 1432, step=1)

# %%
forecast_df= pd.DataFrame(data=MaxTemp, index=MaxTemp_index, columns=['forecast'])

# %%
forecast_df
# Out:
#        forecast
# 1382  24.831656
# 1383  24.235029
# 1384  23.962552
# 1385  24.090516
# 1386  24.550080
# 1387  25.205890
# 1388  25.923574
# 1389  26.597680
# 1390  27.163128
# 1391  27.582565
# 1392  27.864647
# 1393  28.054892
# 1394  28.202889
# 1395  28.348450
# 1396  28.513336
# 1397  28.701506
# 1398  28.898919
# 1399  29.088311
# 1400  29.254267
# 1401  29.387329
# 1402  29.490548
# 1403  29.572371
# 1404  29.639931
# 1405  29.700054
# 1406  29.757807
# 1407  29.813964
# 1408  29.866989
# 1409  29.914873
# 1410  29.955116
# 1411  29.987182
# 1412  30.012039
# 1413  30.031993
# 1414  30.048898
# 1415  30.063952
# 1416  30.077504
# 1417  30.089614
# 1418  30.100170
# 1419  30.108920
# 1420  30.115777
# 1421  30.120836
# 1422  30.124477
# 1423  30.127007
# 1424  30.128700
# 1425  30.129808
# 1426  30.130775
# 1427  30.131953
# 1428  30.133351
# 1429  30.134782
# 1430  30.136032
# 1431  30.136951

# %% [markdown]
# ### Plot the Forecast

# %%
df.plot()
forecast_df.plot()
# Out:
# <AxesSubplot:>

# %%
ax= df.plot()
forecast_df.plot(ax=ax, figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
dir_path_dataset_2= 'C:/Users/anand/Downloads/Weather report 2010_Apr-Jun.csv'

# %%
df_ALL_forecast= pd.read_csv('C:/Users/anand/Downloads/Weather report 2010_Apr-Jun.csv')

# %%
df_ALL_forecast.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  23-04-2010   Albury     11.3     29.0       0.0          NaN       NaN
# 1  24-04-2010   Albury     15.4     19.8       3.6          NaN       NaN
# 2  25-04-2010   Albury     10.8     18.5      17.0          NaN       NaN
# 3  26-04-2010   Albury      5.1     17.9       0.0          NaN       NaN
# 4  27-04-2010   Albury      7.1     16.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         NNW             35        ESE  ...          89           34
# 1         NNW             46        NNE  ...          95           86
# 2           W             37        WSW  ...          72           40
# 3         SSE             15          E  ...          78           49
# 4         ENE             17        NaN  ...          84           58
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1020.5       1014.0       1.0       NaN     15.4     27.9         No
# 1       1013.4       1008.7       8.0       8.0     17.1     18.6        Yes
# 2       1016.2       1017.6       NaN       NaN     14.4     18.4        Yes
# 3       1026.5       1023.0       NaN       NaN     10.4     16.9         No
# 4       1020.9       1018.0       6.0       7.0      9.7     15.9         No
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2            No
# 3            No
# 4           Yes
#
# [5 rows x 23 columns]

# %%
df_ALL_forecast = df_ALL_forecast.iloc[:, 3:4]

# %%
df_ALL_forecast
# Out:
#     MaxTemp
# 0      29.0
# 1      19.8
# 2      18.5
# 3      17.9
# 4      16.1
# 5      17.3
# 6      17.7
# 7      19.1
# 8      21.1
# 9      20.7
# 10     23.0
# 11     25.3
# 12     14.5
# 13     15.3
# 14     17.5
# 15     19.3
# 16     19.5
# 17     19.8
# 18     15.6
# 19     14.9
# 20     17.1
# 21     17.7
# 22     18.4
# 23     17.5
# 24     17.0
# 25     19.7
# 26     18.5
# 27     16.5
# 28     17.9
# 29     17.1
# 30     18.1
# 31     16.3
# 32     14.9
# 33     19.0
# 34     16.6
# 35     17.0
# 36     15.0
# 37     20.2
# 38     19.1
# 39     16.6
# 40     17.7
# 41     17.7
# 42     18.4
# 43     10.2
# 44     15.8
# 45     14.0
# 46     12.2
# 47      8.4
# 48     12.9
# 49     13.2

# %%
df_ALL_forecast.plot()
# Out:
# <AxesSubplot:>

# %%
forecast_df['forecast'].values
# Out:
# array([24.83165639, 24.23502866, 23.96255229, 24.09051648, 24.55007977,
#        25.20589023, 25.92357433, 26.59768019, 27.1631284 , 27.58256463,
#        27.86464736, 28.05489205, 28.20288923, 28.34844964, 28.51333622,
#        28.70150627, 28.89891946, 29.08831117, 29.2542667 , 29.38732913,
#        29.49054822, 29.57237086, 29.63993067, 29.70005363, 29.75780746,
#        29.8139644 , 29.86698867, 29.91487325, 29.95511594, 29.98718225,
#        30.0120386 , 30.03199306, 30.04889773, 30.06395247, 30.07750413,
#        30.08961381, 30.10017023, 30.10892035, 30.1157769 , 30.12083586,
#        30.12447684, 30.12700741, 30.12870028, 30.1298085 , 30.13077492,
#        30.13195294, 30.1333513 , 30.13478239, 30.1360324 , 30.13695083])

# %%
df_ALL_forecast['forecast'] = forecast_df['forecast'].values

# %%
df_ALL_forecast
# Out:
#     MaxTemp   forecast
# 0      29.0  24.831656
# 1      19.8  24.235029
# 2      18.5  23.962552
# 3      17.9  24.090516
# 4      16.1  24.550080
# 5      17.3  25.205890
# 6      17.7  25.923574
# 7      19.1  26.597680
# 8      21.1  27.163128
# 9      20.7  27.582565
# 10     23.0  27.864647
# 11     25.3  28.054892
# 12     14.5  28.202889
# 13     15.3  28.348450
# 14     17.5  28.513336
# 15     19.3  28.701506
# 16     19.5  28.898919
# 17     19.8  29.088311
# 18     15.6  29.254267
# 19     14.9  29.387329
# 20     17.1  29.490548
# 21     17.7  29.572371
# 22     18.4  29.639931
# 23     17.5  29.700054
# 24     17.0  29.757807
# 25     19.7  29.813964
# 26     18.5  29.866989
# 27     16.5  29.914873
# 28     17.9  29.955116
# 29     17.1  29.987182
# 30     18.1  30.012039
# 31     16.3  30.031993
# 32     14.9  30.048898
# 33     19.0  30.063952
# 34     16.6  30.077504
# 35     17.0  30.089614
# 36     15.0  30.100170
# 37     20.2  30.108920
# 38     19.1  30.115777
# 39     16.6  30.120836
# 40     17.7  30.124477
# 41     17.7  30.127007
# 42     18.4  30.128700
# 43     10.2  30.129808
# 44     15.8  30.130775
# 45     14.0  30.131953
# 46     12.2  30.133351
# 47      8.4  30.134782
# 48     12.9  30.136032
# 49     13.2  30.136951

# %%
df_ALL_forecast.plot()
# Out:
# <AxesSubplot:>
